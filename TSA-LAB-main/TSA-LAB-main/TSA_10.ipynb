# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR
from statsmodels.tools.eval_measures import rmse

df = pd.read_csv('/content/multivariate_time_series.csv', parse_dates=['Date'], index_col='Date')
print("Loaded data:\n", df.head())

df = df.astype(float)

n_obs = 10
train, test = df[:-n_obs], df[-n_obs:]

model = VAR(train)
lag_order = model.select_order(maxlags=15)
print("Selected Lag Order:\n", lag_order.summary())

model_fitted = model.fit(lag_order.aic)
print(model_fitted.summary())

forecast_input = train.values[-model_fitted.k_ar:]
forecast = model_fitted.forecast(y=forecast_input, steps=n_obs)

forecast_df = pd.DataFrame(forecast, index=test.index, columns=test.columns)
print("\nForecast:\n", forecast_df)

# === Step 6: Plot Forecast vs Actual ===
for column in df.columns:
    plt.figure(figsize=(10, 4))
    plt.plot(train.index, train[column], label='Training')
    plt.plot(test.index, test[column], label='Actual')
    plt.plot(forecast_df.index, forecast_df[column], label='Forecast', linestyle='--')
    plt.title(f'Forecast vs Actuals for {column}')
    plt.legend()
    plt.show()

for col in df.columns:
    error = rmse(test[col], forecast_df[col])
    print(f'RMSE for {col}: {error:.2f}')
# Out:
# Loaded data:
#                  Sales  Temperature     Demand
# Date
# 2023-01-01  56.641805    30.443854  40.530161
# 2023-01-02  57.945924    30.732893  44.558614
# 2023-01-03  65.999173    31.341150  52.815069
# 2023-01-04  73.985583    31.397814  59.329409
# 2023-01-05  68.159791    29.052155  53.177637
# Selected Lag Order:
#   VAR Order Selection (* highlights the minimums)
# ==================================================
#        AIC         BIC         FPE         HQIC
# --------------------------------------------------
# 0        10.25       10.30   2.830e+04       10.27
# 1        6.843       7.060       937.5       6.931
# 2        6.599      6.979*       734.7       6.753
# 3        6.534       7.077       688.4       6.754
# 4        6.462       7.167       640.9      6.748*
# 5        6.418       7.286       613.6       6.770
# 6       6.372*       7.403      586.6*       6.790
# 7        6.423       7.616       618.2       6.907
# 8        6.457       7.813       641.0       7.007
# 9        6.396       7.915       604.6       7.012
# 10       6.421       8.103       621.6       7.103
# 11       6.402       8.247       612.3       7.151
# 12       6.411       8.418       620.3       7.225
# 13       6.418       8.588       628.3       7.299
# 14       6.455       8.788       655.9       7.402
# 15       6.435       8.931       647.5       7.447
# --------------------------------------------------
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 15, Apr, 2025
# Time:                     02:56:45
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    7.41517
# Nobs:                     184.000    HQIC:                   6.82291
# Log likelihood:          -1316.82    FPE:                    614.900
# AIC:                      6.41924    Det(Omega_mle):         457.899
# --------------------------------------------------------------------
# Results for equation Sales
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.943881        11.223729            0.084           0.933
# L1.Sales               0.535205         0.148069            3.615           0.000
# L1.Temperature        -0.308918         0.458624           -0.674           0.501
# L1.Demand              0.118704         0.166708            0.712           0.476
# L2.Sales               0.271416         0.154461            1.757           0.079
# L2.Temperature        -0.542229         0.455262           -1.191           0.234
# L2.Demand              0.234959         0.167257            1.405           0.160
# L3.Sales              -0.103931         0.153756           -0.676           0.499
# L3.Temperature        -0.527316         0.468698           -1.125           0.261
# L3.Demand              0.384486         0.165963            2.317           0.021
# L4.Sales              -0.031836         0.153335           -0.208           0.836
# L4.Temperature        -1.042693         0.470583           -2.216           0.027
# L4.Demand             -0.120710         0.164895           -0.732           0.464
# L5.Sales               0.196160         0.152455            1.287           0.198
# L5.Temperature         1.418605         0.460474            3.081           0.002
# L5.Demand             -0.257657         0.166399           -1.548           0.122
# L6.Sales              -0.271122         0.144122           -1.881           0.060
# L6.Temperature         1.107325         0.473097            2.341           0.019
# L6.Demand              0.092132         0.164381            0.560           0.575
# =================================================================================
#
# Results for equation Temperature
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  3.453472         1.878043            1.839           0.066
# L1.Sales               0.032370         0.024776            1.306           0.191
# L1.Temperature         0.131302         0.076741            1.711           0.087
# L1.Demand             -0.033505         0.027895           -1.201           0.230
# L2.Sales              -0.019924         0.025846           -0.771           0.441
# L2.Temperature         0.224830         0.076178            2.951           0.003
# L2.Demand              0.026577         0.027987            0.950           0.342
# L3.Sales              -0.000717         0.025728           -0.028           0.978
# L3.Temperature         0.219108         0.078426            2.794           0.005
# L3.Demand             -0.016345         0.027770           -0.589           0.556
# L4.Sales              -0.016094         0.025657           -0.627           0.530
# L4.Temperature         0.070071         0.078742            0.890           0.374
# L4.Demand              0.008516         0.027591            0.309           0.758
# L5.Sales               0.020844         0.025510            0.817           0.414
# L5.Temperature         0.110561         0.077050            1.435           0.151
# L5.Demand             -0.009577         0.027843           -0.344           0.731
# L6.Sales              -0.015987         0.024116           -0.663           0.507
# L6.Temperature         0.156111         0.079162            1.972           0.049
# L6.Demand              0.016883         0.027505            0.614           0.539
# =================================================================================
#
# Results for equation Demand
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                 10.338734        10.008208            1.033           0.302
# L1.Sales               0.325512         0.132033            2.465           0.014
# L1.Temperature        -0.025042         0.408955           -0.061           0.951
# L1.Demand              0.181446         0.148654            1.221           0.222
# L2.Sales               0.267883         0.137733            1.945           0.052
# L2.Temperature        -0.446029         0.405957           -1.099           0.272
# L2.Demand              0.126871         0.149143            0.851           0.395
# L3.Sales              -0.069645         0.137105           -0.508           0.611
# L3.Temperature        -0.769844         0.417939           -1.842           0.065
# L3.Demand              0.375023         0.147989            2.534           0.011
# L4.Sales               0.028934         0.136729            0.212           0.832
# L4.Temperature        -0.775498         0.419619           -1.848           0.065
# L4.Demand             -0.248464         0.147037           -1.690           0.091
# L5.Sales               0.210947         0.135944            1.552           0.121
# L5.Temperature         1.137055         0.410605            2.769           0.006
# L5.Demand             -0.184389         0.148378           -1.243           0.214
# L6.Sales              -0.179236         0.128514           -1.395           0.163
# L6.Temperature         0.689975         0.421861            1.636           0.102
# L6.Demand             -0.033675         0.146578           -0.230           0.818
# =================================================================================
#
# Correlation matrix of residuals
#                   Sales  Temperature    Demand
# Sales          1.000000    -0.013608  0.855716
# Temperature   -0.013608     1.000000 -0.008903
# Demand         0.855716    -0.008903  1.000000
#
#
#
#
# Forecast:
#                   Sales  Temperature      Demand
# Date
# 2023-07-10  151.296891    30.130620  120.662551
# 2023-07-11  147.373278    29.728076  118.717875
# 2023-07-12  144.614688    29.896418  115.890323
# 2023-07-13  143.000293    30.049391  114.778967
# 2023-07-14  138.332819    29.911699  110.534849
# 2023-07-15  134.511314    29.782534  108.199285
# 2023-07-16  131.487474    29.903125  105.515145
# 2023-07-17  127.814318    29.921065  102.350457
# 2023-07-18  125.182712    29.985066  100.635820
# 2023-07-19  122.044965    30.022928   97.827786
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# RMSE for Sales: 9.26
# RMSE for Temperature: 1.44
# RMSE for Demand: 7.06
